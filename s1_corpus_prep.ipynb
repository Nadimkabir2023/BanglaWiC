# %% [markdown]
# ****Prothom Alo Corpus****

# %% [markdown]
# **Batch Filter “body” Column from the archived Prothom Alo corpus and Save to a New Folder**
#
# This code scans a folder of CSV files, extracts the body column from each file (when present), and saves a new CSV per source file containing only sentences (data) into a separate output directory. It creates the output directory if it doesn’t already exist and prints a status message for each file processed.

# %%
# Import the standard library module for filesystem path handling and directory operations
import os
# Import pandas for reading and writing CSV files as DataFrames
import pandas as pd

# Absolute path to the folder containing the original CSV files to process
input_folder = r'C:\Users\Student\Documents\Bangla\archive\csv'                # Folder with your original CSVs
# Absolute path to the destination folder where filtered CSVs (body-only) will be written
output_folder = r'C:\Users\Student\Documents\Bangla\Filtered_archive'          # Folder to save body-only files

# Create the output directory if it doesn't already exist (no error if it does)
os.makedirs(output_folder, exist_ok=True)

# Build a list of filenames in input_folder that end with ".csv"
csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]

# Iterate over each CSV filename discovered in the input folder
for fname in csv_files:
    # Construct the full path to the current CSV file
    fpath = os.path.join(input_folder, fname)
    try:
        # Read the CSV into a pandas DataFrame (uses pandas’ default dtype inference)
        df = pd.read_csv(fpath)
        # Check whether the DataFrame contains a column named "body"
        if 'body' in df.columns:
            # Slice the DataFrame to keep only the "body" column
            body_df = df[['body']]
            # Construct the output filename by appending "_body_only" before the .csv extension
            out_fname = fname.replace('.csv', '_body_only.csv')
            # Build the full output path under output_folder
            out_path = os.path.join(output_folder, out_fname)
            # Write the single-column DataFrame to disk (no index column)
            body_df.to_csv(out_path, index=False)
            # Print a success message with the destination path
            print(f"Saved: {out_path}")
        else:
            # If "body" does not exist, report that this file was skipped
            print(f"Skipped {fname}: No 'body' column found.")
    except Exception as e:
        # If anything goes wrong while reading/writing, log a warning with the error message
        print(f"Error processing {fname}: {e}")
# Out:
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2009-07_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2009-08_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2009-09_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2009-10_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2009-11_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2009-12_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2010-01_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2010-02_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2010-03_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2010-04_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2010-05_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2010-06_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2010-07_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2010-08_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2010-09_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2010-10_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2010-11_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2010-12_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2011-01_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2011-02_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2011-03_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2011-04_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2011-05_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2011-06_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2011-07_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2011-08_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2011-09_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2011-10_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2011-11_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2011-12_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2012-01_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2012-02_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2012-03_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2012-04_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2012-05_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2012-06_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2012-07_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2012-08_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2012-09_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2012-10_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2012-11_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2012-12_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2013-01_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2013-02_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2013-03_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2013-04_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2013-05_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2013-06_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2013-07_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2013-08_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2013-09_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2013-10_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2013-11_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2013-12_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2014-01_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2014-02_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2014-03_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2014-04_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2014-05_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2014-06_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2014-07_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2014-08_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2014-09_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2014-10_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2014-11_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2014-12_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2015-01_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2015-02_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2015-03_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2015-04_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2015-05_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2015-06_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2015-07_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2015-08_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2015-09_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2015-10_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2015-11_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2015-12_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2016-01_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2016-02_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2016-03_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2016-04_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2016-05_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2016-06_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2016-07_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2016-08_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2016-09_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2016-10_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2016-11_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2016-12_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2017-01_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2017-02_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2017-03_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2017-04_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2017-05_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2017-06_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2017-07_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2017-08_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2017-09_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2017-10_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2017-11_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2017-12_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2018-01_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2018-02_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2018-03_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2018-04_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2018-05_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2018-06_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2018-07_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2018-08_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2018-09_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2018-10_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2018-11_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2018-12_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2019-01_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2019-02_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2019-03_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2019-04_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2019-05_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2019-06_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2019-07_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2019-08_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2019-09_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2019-10_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2019-11_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2019-12_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2020-01_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2020-02_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2020-03_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2020-04_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2020-05_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2020-06_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2020-07_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2020-08_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2020-09_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2020-10_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2020-11_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2020-12_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2021-01_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2021-02_body_only.csv
# Saved: C:\Users\Student\Documents\Bangla\Filtered_archive\2021-03_body_only.csv

# %% [markdown]
# **Bangla Sentence Tokenization Pipeline (Regex-Based Tokenization with Length Filter) for CSV “body” Fields**
#
# This code scans a folder of CSV files, reads the body column from each file, splits the text into Bangla sentences using a regex-based tokenizer (splitting on ।, !, ?), filters out very short sentences (≤ 2 words), and writes the remaining sentences to a .txt file (one sentence per line) in an output directory. It also creates the output directory if it doesn’t exist and prints a status line per file.

# %%
import os                                         # Filesystem utilities for paths and directory listing
import pandas as pd                               # DataFrame-based CSV loading/processing
import re                                         # Regular expressions for sentence splitting

input_folder = r'C:\Users\Student\Documents\Bangla\Filtered_archive'     # Source directory containing input CSV files
output_folder = r'C:\Users\Student\Documents\Bangla\Tokenized_archive'   # Destination directory for sentence text files
os.makedirs(output_folder, exist_ok=True)         # Ensure the output directory exists (no error if already present)


# Function bn_sentence_tokenize(text)
# Purpose: Split a Bangla text into sentences by recognizing end-of-sentence punctuation (Dari ।, exclamation !, and question mark ?).
# Inputs:
#   text (Any): The input text; will be coerced to str.
# Outputs:
#   List[str]: A list of trimmed sentence strings with empty fragments removed.
def bn_sentence_tokenize(text):                   # Define a simple Bangla sentence tokenizer using regex
    # Split by Bangla sentence enders (।, !, ?)
    return [s.strip() for s in re.split(r'(?<=[।!?])', str(text)) if s.strip()]  # Split on enders, trim, and drop empties

csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]  # Collect all .csv filenames from the input folder

for fname in csv_files:                           # Iterate over each CSV file to process
    in_path = os.path.join(input_folder, fname)   # Build absolute path to the input CSV
    out_fname = fname.replace('.csv', '_sentences.txt')  # Derive output filename by changing extension
    out_path = os.path.join(output_folder, out_fname)    # Build absolute path to the output text file
    
    try:                                          # Guard the per-file pipeline with error handling
        df = pd.read_csv(in_path)                 # Read the CSV into a DataFrame
        sentences = []                            # Initialize accumulator for tokenized sentences
        for text in df['body'].dropna():          # Iterate over non-null entries in the 'body' column
            sentences.extend(bn_sentence_tokenize(text))  # Tokenize the text and append all sentences
        # Filter out sentences with only 1 or 2 words
        filtered_sentences = [                     # Build a filtered list of sentences
            sent for sent in sentences 
            if len(sent.split()) > 2               # Keep sentences strictly longer than 2 words
        ]
        with open(out_path, 'w', encoding='utf-8') as f:  # Open the destination file for UTF-8 writing
            for sent in filtered_sentences:        # Write each filtered sentence on its own line
                f.write(sent.strip() + '\n')       # Trim whitespace and append newline
        print(f"Tokenized and saved: {out_path}")  # Success message for this file
    except Exception as e:                         # Catch any exception that occurs while processing this file
        print(f"Error processing {fname}: {e}")   # Print a diagnostic error message
# Out:
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2009-07_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2009-08_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2009-09_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2009-10_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2009-11_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2009-12_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2010-01_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2010-02_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2010-03_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2010-04_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2010-05_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2010-06_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2010-07_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2010-08_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2010-09_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2010-10_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2010-11_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2010-12_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2011-01_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2011-02_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2011-03_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2011-04_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2011-05_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2011-06_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2011-07_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2011-08_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2011-09_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2011-10_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2011-11_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2011-12_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2012-01_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2012-02_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2012-03_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2012-04_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2012-05_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2012-06_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2012-07_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2012-08_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2012-09_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2012-10_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2012-11_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2012-12_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2013-01_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2013-02_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2013-03_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2013-04_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2013-05_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2013-06_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2013-07_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2013-08_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2013-09_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2013-10_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2013-11_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2013-12_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2014-01_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2014-02_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2014-03_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2014-04_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2014-05_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2014-06_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2014-07_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2014-08_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2014-09_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2014-10_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2014-11_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2014-12_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2015-01_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2015-02_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2015-03_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2015-04_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2015-05_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2015-06_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2015-07_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2015-08_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2015-09_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2015-10_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2015-11_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2015-12_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2016-01_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2016-02_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2016-03_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2016-04_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2016-05_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2016-06_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2016-07_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2016-08_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2016-09_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2016-10_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2016-11_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2016-12_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2017-01_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2017-02_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2017-03_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2017-04_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2017-05_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2017-06_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2017-07_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2017-08_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2017-09_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2017-10_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2017-11_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2017-12_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2018-01_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2018-02_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2018-03_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2018-04_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2018-05_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2018-06_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2018-07_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2018-08_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2018-09_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2018-10_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2018-11_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2018-12_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2019-01_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2019-02_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2019-03_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2019-04_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2019-05_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2019-06_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2019-07_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2019-08_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2019-09_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2019-10_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2019-11_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2019-12_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2020-01_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2020-02_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2020-03_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2020-04_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2020-05_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2020-06_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2020-07_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2020-08_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2020-09_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2020-10_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2020-11_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2020-12_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2021-01_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2021-02_body_only_sentences.txt
# Tokenized and saved: C:\Users\Student\Documents\Bangla\Tokenized_archives\2021-03_body_only_sentences.txt

# %%
import sys # Access the current Python executable path
# !{sys.executable} -m pip install bangla-stemmer # Install 'bangla-stemmer' into this environment
# Out:
# Collecting bangla-stemmer
#   Using cached bangla_stemmer-1.0-py3-none-any.whl.metadata (2.4 kB)
# Using cached bangla_stemmer-1.0-py3-none-any.whl (9.1 kB)
# Installing collected packages: bangla-stemmer
# Successfully installed bangla-stemmer-1.0
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ****Prothom Alo Corpus****

# %% [markdown]
# **Bangla Keyword-Aware Sentence Retriever (Rule-Based with Suffix Matching)**
#
# This code scans a folder of Bangla sentence files (.txt) and extracts sentences that contain any target keyword or a keyword followed by common Bangla inflectional suffixes. It compiles a comprehensive regex for each keyword (lemma + suffix variants with proper word boundaries), searches every line across all files, and writes the matched sentences to per-keyword text files in an output directory. It prints a summary of how many matches were found for each keyword.

# %%
# ---- Standard library imports: filesystem paths/listing, regex utilities, CSV (unused; left for potential extensions)
import os
import re
import csv


# Target keyword list (lemmas) to search for in the corpus
keywords = [
    'অর্থ', 'কপাল', 'রাস্তা', 'মাথা', 'বল', 'হাত', 'ফল', 'চোখ', 'কর', 'পাকা', 'বর', 'জল', 'এঁটে', 'বর্ণ', 'মধু',
    'গভীর', 'তার', 'মূল', 'মুখ', 'কাজ', 'অন্ধকার', 'ঘর', 'ছত্র', 'বক', 'জাম', 'ধরা', 'দাঁড়া', 'গোলা', 'ঝুল', 'কামাই',
    'চড়', 'সন্ধি', 'ফাঁক', 'ঝড়', 'সোজা', 'পটল', 'কাটা', 'জানালা', 'আম', 'দিক', 'কুঁজো', 'বাঁশ', 'বেলা', 'বাজি',
    'তাড়া', 'সারা', 'আগুন', 'সই', 'পথ', 'দল', 'পদ', 'কালা', 'ডিম', 'গুলি', 'বিষয়', 'বিরোধ', 'নয়', 'কান', 'দম',
    'হেলা', 'কুল', 'মাত', 'বন্ধ', 'ঝোলা', 'চড়া', 'রস', 'মাটি', 'মালা', 'ধন', 'পাল', 'কর্ণ', 'আকাশ', 'शীর্ষ',
    'চিহ্ন', 'লাঠি', 'আকা', 'পুষ্কর', 'নাক', 'টোকা', 'শিশু', 'গজ', 'লাই', 'হল', 'স্বামী', 'স্পষ্ট', 'সামান্য',
    'পিচ', 'পাহাড়', 'গা', 'ময়না', 'ঠান্ডা', 'ঘোর', 'পড়া', 'আগ', 'উঠা', 'চাঁদা', 'ঢাকা', 'উপায়', 'তুলা', 'ধোঁয়া',
    'ঘন', 'পর', 'কপি', 'জিন', 'সার', 'পালা', 'পাড়া', 'ফিট', 'চাপ', 'বাড়ি', 'বয়স', 'বাটা', 'চা', 'পাতি', 'ফেলা',
    'জাল', 'পেঁচ', 'হাওয়া', 'মটকা', 'জমি', 'চাবি','কথা','রূপ','বিন্দু','খাতা','শাখা','দরজা','কান্ড','বাকী','নাম','বাকী',
    'ঘটনা','বাজে','দাগ','পাত্র','দ্বার', 'ডাক'
]


# Comprehensive list of common Bangla inflectional suffixes and standalone vowel diacritics
# These are appended to keywords in a regex to catch inflected forms, with word-boundary enforcement.
# Full list of inflectional suffixes + single vowels
suffixes = [
    '', 'কে', 'কেই', 'কেও', 'কেওই', 'কো', 'গুলা', 'গুলা-গুলা', 'গুলাগুলি', 'গুলাগো',
    'গুলান', 'গুলানা', 'গুলানো', 'গুলার', 'গুলারই', 'গুলারও', 'গুলারাই', 'গুলারে', 'গুলারেই', 'গুলারেইও',
    'গুলারটাও', 'গুলারি', 'গুলাটারে', 'গুলাডা', 'গুলাডারে', 'গুলিকেও', 'গুলিকে', 'গুলিকো', 'গুলিতে',
    'গুলিতো', 'গুলিতেও', 'গুলিতেই', 'গুলির', 'গুলিরই', 'গুলিরও', 'গুলিরেই', 'গুলিও', 'গুলিয়েই', 'গুলিয়েও',
    'গুলো', 'গুলাই', 'গুলাইও', 'গুলোই', 'গুলো-গুলো', 'গুলোকেই', 'গুলোকেও', 'গুলোতে', 'গুলোয়', 'গুলোর',
    'গুলোরই', 'গুলোরও', 'গুলোরটাই', 'গুলোরে', 'গুলোরেই', 'গুলান', 'খানা', 'খানাকে', 'খানাতে', 'খানার', 'খানায়',
    'চ্ছে', 'ছে', 'ছেন', 'ছো', 'ছি', 'ছিস', 'ছিসি', 'ছিসেন', 'ছিল', 'ছিলা', 'ছিলাই', 'ছিলাম', 'ছিলি',
    'ছিলে', 'ছিলে না', 'ছিলেন', 'ছিলেনা', 'ছিলনা', 'ছিলো', 'জন', 'জনগো', 'জনকে', 'জনেরা', 'জনের', 'জনে',
    'তা', 'টা', 'টা-টা', 'টাগো', 'টাই', 'টাইও', 'টাইনা', 'টাইওনা', 'টার', 'টারই', 'টারও', 'টারেও',
    'টারটাও', 'টারে', 'টারেই', 'টি', 'টি-টি', 'টিই', 'টিা', 'টিাে', 'টিাও', 'টিায়', 'টিেই', 'টিতে', 'টিতেও',
    'টিতেই', 'টিকে', 'টিকেই', 'টিকেও', 'টির', 'টিরই', 'টিরও', 'টিরে', 'টিরেই', 'টিরটাই', 'টিও', 'টিওনা',
    'টিনাও', 'টিনাওনা', 'টাতো', 'টাতেও', 'টাতে', 'টাকে', 'টায়', 'তাচ্ছি', 'তাছি', 'তবে', 'ত', 'তাম',
    'তি', 'তে', 'তেও', 'তেওই', 'তেওনা', 'তেই', 'তেইও', 'তেন', 'তের', 'তেরই', 'তেরও', 'তেরাই', 'তেরা', 'তেও', 'তো', 'তো',
    'তোও', 'থেকে', 'থেকেই', 'থেকেই না', 'থেকেও', 'থেকেও না', 'দিয়ে', 'দিয়েও', 'দিয়ো', 'দিয়েও না',
    'দের', 'দেরকেই', 'দেরকে', 'দেরকেও', 'দেররাও', 'দেররেই', 'দেররে', 'দেরই', 'দেরও', 'দেরওয়', 'দেরে', 'দেরেই',
    'দেরটাই', 'দেরটাইও', 'দেরনা', 'নাই', 'নাছে', 'নাছি', 'না', 'না’', 'নেই', 'নেও', 'নেওনা', 'নাও', 'নাই', 'নেই', 'ই',
    'ইও', 'ইনা', 'ইওনা', 'ইরা', 'ইগো', 'ইনাই', 'ইতে', 'ইয়', 'ইয়েই', 'ইয়েও', 'ও', 'ওগো', 'ওরা', 'ওরাও', 'ওরাওনা', 'ওরাই',
    'ওদের', 'ওদেরকেও', 'ওদেরকে', 'ওদেররাও', 'ওদেরনা', 'ওদেরই', 'ওদেরও', 'ওদেরটাই', 'ওনি', 'ওন', 'ওনা',
    'এ', 'এতে', 'এরই', 'আমেরটাই', 'ব', 'বে', 'বেন', 'বেনা', 'বেনে', 'বিনা', 'বিনা না', 'বি', 'বো', 'বো না', 'বোনে',
    'বুলছি', 'মেয়েরা', 'পান', 'পানোর', 'পানেও', 'রা', 'রা’', 'রাই', 'রাইও', 'রাইনা', 'রাে', 'রাগো', 'রাও', 'রাওই', 'রাওনা',
    'রাটা', 'রেই', 'রেইও', 'র', 'রের', 'রেরই', 'রেরও', 'রেরে', 'রও', 'লাম', 'লামও', 'লামেই', 'লামনা', 'লি', 'লে', 'লেন', 'লো',
    'তাম', 'তেন', 'হয়', 'হয়েই', 'হয়না', 'সহ', 'সহেই', 'সহেই না', 'সহেও', 'সহেও না', 'য়', 'য়াটা', 'য়ে', 'য়েই', 'য়েই না',
    'য়েইও', 'য়ো', 'য়ো না', 'য়েও', 'য়েও না', 'য়েটা', 'য়াছে', 'য়াছি', 'য়াছিল', 'য়াছিলাম', 'য়াছেন', 'য়াছিলে', 'য়াছিলেন'
] + ['া', 'ি', 'ু', 'ে', 'ো', 'ৈ', 'ৌ']  # Vowel endings (no derivation)


# Function: find_sentences_with_word
# Purpose : For a given keyword (lemma), search all .txt files in a directory and collect sentences containing 
# the lemma or lemma+suffix (from the list). Builds a regex that matches lemma + any suffix from `suffixes`, then enforces a
# word boundary by requiring a trailing whitespace, punctuation, or string end. Uses a negative lookbehind for 
# ASCII word chars to avoid partial matches there. Results are written to <lemma>.txt in the output directory.
# Inputs  :
#   input_directory (str): Path to folder with input .txt files (one sentence per line).
#   lemma_word      (str): The base keyword/lemma to search for.
#   output_directory(str): Path to folder where matched sentences file will be saved.
# Outputs :
#   None (side effects): Writes a text file with one matched sentence per line
#   Prints a completion summary with match count.
def find_sentences_with_word(input_directory, lemma_word, output_directory):
    # Prebuild a suffix alternation pattern, sorted by length (longest first) to ensure greedy matching
    # Make regex pattern for lemma + suffixes, must be followed by boundary (not a Bengali char)
    suffix_regex = '|'.join(sorted([re.escape(s) for s in suffixes if s], key=len, reverse=True))
    # Compose the final pattern:
    #   - capture lemma + one of the suffixes
    #   - enforce ending at boundary: whitespace, Bangla danda/ punctuation, bracket/quote, or string end
    # Force match to end at space, punctuation, or string end
    # Note: [\s।,;:.?!\]\["'\)\(]|$ will match boundary after lemma+suffix
    pattern = re.compile(
        rf'(?<!\w)({re.escape(lemma_word)}({suffix_regex}))(?:[\s।,;:.?!\]\["\'\)\(]|$)'
    )

    # Accumulate matched sentences
    matches = []
    # Iterate all files in the input directory
    for file_name in os.listdir(input_directory):
        # Process only .txt files
        if file_name.endswith('.txt'):
            # Full path to the file
            file_path = os.path.join(input_directory, file_name)
            # Open the file in UTF-8 and scan line by line
            with open(file_path, 'r', encoding='utf-8') as infile:
                for line in infile:
                    # Strip whitespace/newlines
                    line = line.strip()
                    # If the compiled pattern matches anywhere in the line, keep it
                    if pattern.search(line):
                        matches.append([line])

    # Build output filename for this lemma and write one sentence per line
    # Write to txt
    output_file = os.path.join(output_directory, f"{lemma_word}.txt")
    with open(output_file, 'w', encoding='utf-8') as outfile:
        for row in matches:
            outfile.write(row[0] + '\n')

    # Print completion summary with count and destination path
    print(f"Search complete! Found {len(matches)} matching sentences saved to {output_file}.")


# ---- Input/Output directories for the corpus and where to save per-keyword matches
input_directory = r"C:\Users\Student\Documents\Bangla\Tokenized_archive"
output_directory = r"C:\Users\Student\Documents\Bangla\extracted_sentences_prothom_alo"

# ---- Run the search for every keyword in the list, producing one output file per lemma
for lemma_word in keywords:
    find_sentences_with_word(input_directory, lemma_word, output_directory)
# Out:
# Search complete! Found 13569 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\অর্থ.txt.
# Search complete! Found 5415 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\কপাল.txt.
# Search complete! Found 65006 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\রাস্তা.txt.
# Search complete! Found 58411 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\মাথা.txt.
# Search complete! Found 1300518 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\বল.txt.
# Search complete! Found 173001 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\হাত.txt.
# Search complete! Found 147783 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ফল.txt.
# Search complete! Found 42640 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\চোখ.txt.
# Search complete! Found 5061746 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\কর.txt.
# Search complete! Found 998 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\পাকা.txt.
# Search complete! Found 101277 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\বর.txt.
# Search complete! Found 13386 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\জল.txt.
# Search complete! Found 229 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\এঁটে.txt.
# Search complete! Found 19977 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\বর্ণ.txt.
# Search complete! Found 5650 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\মধু.txt.
# Search complete! Found 5666 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\গভীর.txt.
# Search complete! Found 451136 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\তার.txt.
# Search complete! Found 40371 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\মূল.txt.
# Search complete! Found 118594 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\মুখ.txt.
# Search complete! Found 151083 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\কাজ.txt.
# Search complete! Found 5169 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\অন্ধকার.txt.
# Search complete! Found 70437 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ঘর.txt.
# Search complete! Found 128 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ছত্র.txt.
# Search complete! Found 61457 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\বক.txt.
# Search complete! Found 10497 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\জাম.txt.
# Search complete! Found 21227 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ধরা.txt.
# Search complete! Found 4864 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\দাঁড়া.txt.
# Search complete! Found 3702 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\গোলা.txt.
# Search complete! Found 8704 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ঝুল.txt.
# Search complete! Found 56 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\কামাই.txt.
# Search complete! Found 3919 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\চড়.txt.
# Search complete! Found 950 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\সন্ধি.txt.
# Search complete! Found 28587 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ফাঁক.txt.
# Search complete! Found 1488 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ঝড়.txt.
# Search complete! Found 34 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\সোজা.txt.
# Search complete! Found 43 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\পটল.txt.
# Search complete! Found 35757 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\কাটা.txt.
# Search complete! Found 6982 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\জানালা.txt.
# Search complete! Found 898894 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\আম.txt.
# Search complete! Found 406012 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\দিক.txt.
# Search complete! Found 21 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\কুঁজো.txt.
# Search complete! Found 4877 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\বাঁশ.txt.
# Search complete! Found 14005 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\বেলা.txt.
# Search complete! Found 10128 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\বাজি.txt.
# Search complete! Found 234 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\তাড়া.txt.
# Search complete! Found 3533 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\সারা.txt.
# Search complete! Found 12040 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\আগুন.txt.
# Search complete! Found 3297 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\সই.txt.
# Search complete! Found 90347 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\পথ.txt.
# Search complete! Found 169548 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\দল.txt.
# Search complete! Found 82063 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\পদ.txt.
# Search complete! Found 3660 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\কালা.txt.
# Search complete! Found 1248 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ডিম.txt.
# Search complete! Found 25490 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\গুলি.txt.
# Search complete! Found 374044 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\বিষয়.txt.
# Search complete! Found 1722 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\বিরোধ.txt.
# Search complete! Found 60342 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\নয়.txt.
# Search complete! Found 86093 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\কান.txt.
# Search complete! Found 16252 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\দম.txt.
# Search complete! Found 654 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\হেলা.txt.
# Search complete! Found 39824 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\কুল.txt.
# Search complete! Found 35434 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\মাত.txt.
# Search complete! Found 59453 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\বন্ধ.txt.
# Search complete! Found 323 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ঝোলা.txt.
# Search complete! Found 4083 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\চড়া.txt.
# Search complete! Found 20749 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\রস.txt.
# Search complete! Found 45005 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\মাটি.txt.
# Search complete! Found 10542 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\মালা.txt.
# Search complete! Found 38781 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ধন.txt.
# Search complete! Found 21700 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\পাল.txt.
# Search complete! Found 111 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\কর্ণ.txt.
# Search complete! Found 11963 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\আকাশ.txt.
# Search complete! Found 14019 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\শীর্ষ.txt.
# Search complete! Found 1014 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\চিহ্ন.txt.
# Search complete! Found 1701 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\লাঠি.txt.
# Search complete! Found 18956 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\আকা.txt.
# Search complete! Found 5 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\পুষ্কর.txt.
# Search complete! Found 83057 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\নাক.txt.
# Search complete! Found 685 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\টোকা.txt.
# Search complete! Found 126393 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\শিশু.txt.
# Search complete! Found 7546 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\গজ.txt.
# Search complete! Found 8525 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\লাই.txt.
# Search complete! Found 641958 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\হল.txt.
# Search complete! Found 24458 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\স্বামী.txt.
# Search complete! Found 1095 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\স্পষ্ট.txt.
# Search complete! Found 1730 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\সামান্য.txt.
# Search complete! Found 781 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\পিচ.txt.
# Search complete! Found 3639 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\পাহাড়.txt.
# Search complete! Found 176436 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\গা.txt.
# Search complete! Found 53 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ময়না.txt.
# Search complete! Found 1997 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ঠান্ডা.txt.
# Search complete! Found 2078 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ঘোর.txt.
# Search complete! Found 8535 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\পড়া.txt.
# Search complete! Found 405313 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\আগ.txt.
# Search complete! Found 568 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\উঠা.txt.
# Search complete! Found 1765 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\চাঁদা.txt.
# Search complete! Found 178383 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ঢাকা.txt.
# Search complete! Found 7108 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\উপায়.txt.
# Search complete! Found 1180 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\তুলা.txt.
# Search complete! Found 131 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ধোঁয়া.txt.
# Search complete! Found 8743 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ঘন.txt.
# Search complete! Found 383526 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\পর.txt.
# Search complete! Found 1792 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\কপি.txt.
# Search complete! Found 9705 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\জিন.txt.
# Search complete! Found 144801 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\সার.txt.
# Search complete! Found 6076 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\পালা.txt.
# Search complete! Found 3992 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\পাড়া.txt.
# Search complete! Found 137 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ফিট.txt.
# Search complete! Found 32932 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\চাপ.txt.
# Search complete! Found 34004 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\বাড়ি.txt.
# Search complete! Found 2877 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\বয়স.txt.
# Search complete! Found 1462 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\বাটা.txt.
# Search complete! Found 537519 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\চা.txt.
# Search complete! Found 2102 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\পাতি.txt.
# Search complete! Found 16386 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\ফেলা.txt.
# Search complete! Found 11260 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\জাল.txt.
# Search complete! Found 223 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\পেঁচ.txt.
# Search complete! Found 465 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\হাওয়া.txt.
# Search complete! Found 58 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\মটকা.txt.
# Search complete! Found 59368 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences\জমি.txt.

# %% [markdown]
# ****IndicNLP Bangla Corpus (Tokenized)****

# %%
# ---- Standard library imports: filesystem paths/listing, regex utilities, CSV (unused; left for potential extensions)
import os
import re
import csv


# Target keyword list (lemmas) to search for in the corpus
keywords = [
    'অর্থ', 'কপাল', 'রাস্তা', 'মাথা', 'বল', 'হাত', 'ফল', 'চোখ', 'কর', 'পাকা', 'বর', 'জল', 'এঁটে', 'বর্ণ', 'মধু',
    'গভীর', 'তার', 'মূল', 'মুখ', 'কাজ', 'অন্ধকার', 'ঘর', 'ছত্র', 'বক', 'জাম', 'ধরা', 'দাঁড়া', 'গোলা', 'ঝুল', 'কামাই',
    'চড়', 'সন্ধি', 'ফাঁক', 'ঝড়', 'সোজা', 'পটল', 'কাটা', 'জানালা', 'আম', 'দিক', 'কুঁজো', 'বাঁশ', 'বেলা', 'বাজি',
    'তাড়া', 'সারা', 'আগুন', 'সই', 'পথ', 'দল', 'পদ', 'কালা', 'ডিম', 'গুলি', 'বিষয়', 'বিরোধ', 'নয়', 'কান', 'দম',
    'হেলা', 'কুল', 'মাত', 'বন্ধ', 'ঝোলা', 'চড়া', 'রস', 'মাটি', 'মালা', 'ধন', 'পাল', 'কর্ণ', 'আকাশ', 'शীর্ষ',
    'চিহ্ন', 'লাঠি', 'আকা', 'পুষ্কর', 'নাক', 'টোকা', 'শিশু', 'গজ', 'লাই', 'হল', 'স্বামী', 'স্পষ্ট', 'সামান্য',
    'পিচ', 'পাহাড়', 'গা', 'ময়না', 'ঠান্ডা', 'ঘোর', 'পড়া', 'আগ', 'উঠা', 'চাঁদা', 'ঢাকা', 'উপায়', 'তুলা', 'ধোঁয়া',
    'ঘন', 'পর', 'কপি', 'জিন', 'সার', 'পালা', 'পাড়া', 'ফিট', 'চাপ', 'বাড়ি', 'বয়স', 'বাটা', 'চা', 'পাতি', 'ফেলা',
    'জাল', 'পেঁচ', 'হাওয়া', 'মটকা', 'জমি', 'চাবি','কথা','রূপ','বিন্দু','খাতা','শাখা','দরজা','কান্ড','বাকী','নাম','বাকী',
    'ঘটনা','বাজে','দাগ','পাত্র','দ্বার', 'ডাক'
]


# Comprehensive list of common Bangla inflectional suffixes and standalone vowel diacritics
# These are appended to keywords in a regex to catch inflected forms, with word-boundary enforcement.
# Full list of inflectional suffixes + single vowels
suffixes = [
    '', 'কে', 'কেই', 'কেও', 'কেওই', 'কো', 'গুলা', 'গুলা-গুলা', 'গুলাগুলি', 'গুলাগো',
    'গুলান', 'গুলানা', 'গুলানো', 'গুলার', 'গুলারই', 'গুলারও', 'গুলারাই', 'গুলারে', 'গুলারেই', 'গুলারেইও',
    'গুলারটাও', 'গুলারি', 'গুলাটারে', 'গুলাডা', 'গুলাডারে', 'গুলিকেও', 'গুলিকে', 'গুলিকো', 'গুলিতে',
    'গুলিতো', 'গুলিতেও', 'গুলিতেই', 'গুলির', 'গুলিরই', 'গুলিরও', 'গুলিরেই', 'গুলিও', 'গুলিয়েই', 'গুলিয়েও',
    'গুলো', 'গুলাই', 'গুলাইও', 'গুলোই', 'গুলো-গুলো', 'গুলোকেই', 'গুলোকেও', 'গুলোতে', 'গুলোয়', 'গুলোর',
    'গুলোরই', 'গুলোরও', 'গুলোরটাই', 'গুলোরে', 'গুলোরেই', 'গুলান', 'খানা', 'খানাকে', 'খানাতে', 'খানার', 'খানায়',
    'চ্ছে', 'ছে', 'ছেন', 'ছো', 'ছি', 'ছিস', 'ছিসি', 'ছিসেন', 'ছিল', 'ছিলা', 'ছিলাই', 'ছিলাম', 'ছিলি',
    'ছিলে', 'ছিলে না', 'ছিলেন', 'ছিলেনা', 'ছিলনা', 'ছিলো', 'জন', 'জনগো', 'জনকে', 'জনেরা', 'জনের', 'জনে',
    'তা', 'টা', 'টা-টা', 'টাগো', 'টাই', 'টাইও', 'টাইনা', 'টাইওনা', 'টার', 'টারই', 'টারও', 'টারেও',
    'টারটাও', 'টারে', 'টারেই', 'টি', 'টি-টি', 'টিই', 'টিা', 'টিাে', 'টিাও', 'টিায়', 'টিেই', 'টিতে', 'টিতেও',
    'টিতেই', 'টিকে', 'টিকেই', 'টিকেও', 'টির', 'টিরই', 'টিরও', 'টিরে', 'টিরেই', 'টিরটাই', 'টিও', 'টিওনা',
    'টিনাও', 'টিনাওনা', 'টাতো', 'টাতেও', 'টাতে', 'টাকে', 'টায়', 'তাচ্ছি', 'তাছি', 'তবে', 'ত', 'তাম',
    'তি', 'তে', 'তেও', 'তেওই', 'তেওনা', 'তেই', 'তেইও', 'তেন', 'তের', 'তেরই', 'তেরও', 'তেরাই', 'তেরা', 'তেও', 'তো', 'তো',
    'তোও', 'থেকে', 'থেকেই', 'থেকেই না', 'থেকেও', 'থেকেও না', 'দিয়ে', 'দিয়েও', 'দিয়ো', 'দিয়েও না',
    'দের', 'দেরকেই', 'দেরকে', 'দেরকেও', 'দেররাও', 'দেররেই', 'দেররে', 'দেরই', 'দেরও', 'দেরওয়', 'দেরে', 'দেরেই',
    'দেরটাই', 'দেরটাইও', 'দেরনা', 'নাই', 'নাছে', 'নাছি', 'না', 'না’', 'নেই', 'নেও', 'নেওনা', 'নাও', 'নাই', 'নেই', 'ই',
    'ইও', 'ইনা', 'ইওনা', 'ইরা', 'ইগো', 'ইনাই', 'ইতে', 'ইয়', 'ইয়েই', 'ইয়েও', 'ও', 'ওগো', 'ওরা', 'ওরাও', 'ওরাওনা', 'ওরাই',
    'ওদের', 'ওদেরকেও', 'ওদেরকে', 'ওদেররাও', 'ওদেরনা', 'ওদেরই', 'ওদেরও', 'ওদেরটাই', 'ওনি', 'ওন', 'ওনা',
    'এ', 'এতে', 'এরই', 'আমেরটাই', 'ব', 'বে', 'বেন', 'বেনা', 'বেনে', 'বিনা', 'বিনা না', 'বি', 'বো', 'বো না', 'বোনে',
    'বুলছি', 'মেয়েরা', 'পান', 'পানোর', 'পানেও', 'রা', 'রা’', 'রাই', 'রাইও', 'রাইনা', 'রাে', 'রাগো', 'রাও', 'রাওই', 'রাওনা',
    'রাটা', 'রেই', 'রেইও', 'র', 'রের', 'রেরই', 'রেরও', 'রেরে', 'রও', 'লাম', 'লামও', 'লামেই', 'লামনা', 'লি', 'লে', 'লেন', 'লো',
    'তাম', 'তেন', 'হয়', 'হয়েই', 'হয়না', 'সহ', 'সহেই', 'সহেই না', 'সহেও', 'সহেও না', 'য়', 'য়াটা', 'য়ে', 'য়েই', 'য়েই না',
    'য়েইও', 'য়ো', 'য়ো না', 'য়েও', 'য়েও না', 'য়েটা', 'য়াছে', 'য়াছি', 'য়াছিল', 'য়াছিলাম', 'য়াছেন', 'য়াছিলে', 'য়াছিলেন'
] + ['া', 'ি', 'ু', 'ে', 'ো', 'ৈ', 'ৌ']  # Vowel endings (no derivation)


# Function: find_sentences_with_word
# Purpose : For a given keyword (lemma), search all .txt files in a directory and collect sentences containing 
# the lemma or lemma+suffix (from the list). Builds a regex that matches lemma + any suffix from `suffixes`, then enforces a
# word boundary by requiring a trailing whitespace, punctuation, or string end. Uses a negative lookbehind for 
# ASCII word chars to avoid partial matches there. Results are written to <lemma>.txt in the output directory.
# Inputs  :
#   input_directory (str): Path to folder with input .txt files (one sentence per line).
#   lemma_word      (str): The base keyword/lemma to search for.
#   output_directory(str): Path to folder where matched sentences file will be saved.
# Outputs :
#   None (side effects): Writes a text file with one matched sentence per line
#   Prints a completion summary with match count.
def find_sentences_with_word(input_directory, lemma_word, output_directory):
    # Prebuild a suffix alternation pattern, sorted by length (longest first) to ensure greedy matching
    # Make regex pattern for lemma + suffixes, must be followed by boundary (not a Bengali char)
    suffix_regex = '|'.join(sorted([re.escape(s) for s in suffixes if s], key=len, reverse=True))
    # Compose the final pattern:
    #   - capture lemma + one of the suffixes
    #   - enforce ending at boundary: whitespace, Bangla danda/ punctuation, bracket/quote, or string end
    # Force match to end at space, punctuation, or string end
    # Note: [\s।,;:.?!\]\["'\)\(]|$ will match boundary after lemma+suffix
    pattern = re.compile(
        rf'(?<!\w)({re.escape(lemma_word)}({suffix_regex}))(?:[\s।,;:.?!\]\["\'\)\(]|$)'
    )

    # Accumulate matched sentences
    matches = []
    # Iterate all files in the input directory
    for file_name in os.listdir(input_directory):
        # Process only .txt files
        if file_name.endswith('.txt'):
            # Full path to the file
            file_path = os.path.join(input_directory, file_name)
            # Open the file in UTF-8 and scan line by line
            with open(file_path, 'r', encoding='utf-8') as infile:
                for line in infile:
                    # Strip whitespace/newlines
                    line = line.strip()
                    # If the compiled pattern matches anywhere in the line, keep it
                    if pattern.search(line):
                        matches.append([line])

    # Build output filename for this lemma and write one sentence per line
    # Write to txt
    output_file = os.path.join(output_directory, f"{lemma_word}.txt")
    with open(output_file, 'w', encoding='utf-8') as outfile:
        for row in matches:
            outfile.write(row[0] + '\n')

    # Print completion summary with count and destination path
    print(f"Search complete! Found {len(matches)} matching sentences saved to {output_file}.")


# ---- Input/Output directories for the corpus and where to save per-keyword matches
input_directory = r"C:\Users\Student\Documents\Bangla\split_parts"
output_directory = r"C:\Users\Student\Documents\Bangla\extracted_sentences_indic"

# ---- Run the search for every keyword in the list, producing one output file per lemma
for lemma_word in keywords:
    find_sentences_with_word(input_directory, lemma_word, output_directory)
# Out:
# Search complete! Found 32334 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\অর্থ.txt.
# Search complete! Found 24405 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\কপাল.txt.
# Search complete! Found 94268 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\রাস্তা.txt.
# Search complete! Found 61598 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\মাথা.txt.
# Search complete! Found 3682752 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বল.txt.
# Search complete! Found 531707 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\হাত.txt.
# Search complete! Found 486865 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ফল.txt.
# Search complete! Found 148729 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\চোখ.txt.
# Search complete! Found 13098209 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\কর.txt.
# Search complete! Found 3287 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\পাকা.txt.
# Search complete! Found 279467 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বর.txt.
# Search complete! Found 81958 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\জল.txt.
# Search complete! Found 1655 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\এঁটে.txt.
# Search complete! Found 68889 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বর্ণ.txt.
# Search complete! Found 20798 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\মধু.txt.
# Search complete! Found 17574 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\গভীর.txt.
# Search complete! Found 1454642 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\তার.txt.
# Search complete! Found 107143 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\মূল.txt.
# Search complete! Found 397109 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\মুখ.txt.
# Search complete! Found 338606 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\কাজ.txt.
# Search complete! Found 27678 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\অন্ধকার.txt.
# Search complete! Found 235281 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ঘর.txt.
# Search complete! Found 867 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ছত্র.txt.
# Search complete! Found 202978 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বক.txt.
# Search complete! Found 42435 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\জাম.txt.
# Search complete! Found 46672 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ধরা.txt.
# Search complete! Found 77497 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\দাঁড়া.txt.
# Search complete! Found 9663 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\গোলা.txt.
# Search complete! Found 24611 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ঝুল.txt.
# Search complete! Found 137 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\কামাই.txt.
# Search complete! Found 67665 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\চড়.txt.
# Search complete! Found 3063 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\সন্ধি.txt.
# Search complete! Found 64001 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ফাঁক.txt.
# Search complete! Found 25428 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ঝড়.txt.
# Search complete! Found 166 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\সোজা.txt.
# Search complete! Found 483 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\পটল.txt.
# Search complete! Found 79311 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\কাটা.txt.
# Search complete! Found 12275 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\জানালা.txt.
# Search complete! Found 2523922 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\আম.txt.
# Search complete! Found 965459 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\দিক.txt.
# Search complete! Found 213 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\কুঁজো.txt.
# Search complete! Found 8806 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বাঁশ.txt.
# Search complete! Found 16539 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বেলা.txt.
# Search complete! Found 18431 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বাজি.txt.
# Search complete! Found 5174 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\তাড়া.txt.
# Search complete! Found 14104 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\সারা.txt.
# Search complete! Found 31434 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\আগুন.txt.
# Search complete! Found 8744 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\সই.txt.
# Search complete! Found 236163 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\পথ.txt.
# Search complete! Found 345479 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\দল.txt.
# Search complete! Found 186230 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\পদ.txt.
# Search complete! Found 10726 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\কালা.txt.
# Search complete! Found 5168 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ডিম.txt.
# Search complete! Found 140274 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\গুলি.txt.
# Search complete! Found 0 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বিষয়.txt.
# Search complete! Found 5200 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বিরোধ.txt.
# Search complete! Found 0 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\নয়.txt.
# Search complete! Found 188666 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\কান.txt.
# Search complete! Found 28039 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\দম.txt.
# Search complete! Found 1142 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\হেলা.txt.
# Search complete! Found 123761 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\কুল.txt.
# Search complete! Found 100800 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\মাত.txt.
# Search complete! Found 175587 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বন্ধ.txt.
# Search complete! Found 1127 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ঝোলা.txt.
# Search complete! Found 0 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\চড়া.txt.
# Search complete! Found 62793 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\রস.txt.
# Search complete! Found 133259 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\মাটি.txt.
# Search complete! Found 15107 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\মালা.txt.
# Search complete! Found 106005 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ধন.txt.
# Search complete! Found 65213 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\পাল.txt.
# Search complete! Found 1708 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\কর্ণ.txt.
# Search complete! Found 39825 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\আকাশ.txt.
# Search complete! Found 0 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\शীর্ষ.txt.
# Search complete! Found 3997 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\চিহ্ন.txt.
# Search complete! Found 5589 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\লাঠি.txt.
# Search complete! Found 46542 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\আকা.txt.
# Search complete! Found 104 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\পুষ্কর.txt.
# Search complete! Found 264255 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\নাক.txt.
# Search complete! Found 1187 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\টোকা.txt.
# Search complete! Found 261857 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\শিশু.txt.
# Search complete! Found 30648 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\গজ.txt.
# Search complete! Found 11499 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\লাই.txt.
# Search complete! Found 1446634 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\হল.txt.
# Search complete! Found 86490 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\স্বামী.txt.
# Search complete! Found 4447 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\স্পষ্ট.txt.
# Search complete! Found 3133 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\সামান্য.txt.
# Search complete! Found 6576 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\পিচ.txt.
# Search complete! Found 52780 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\পাহাড়.txt.
# Search complete! Found 458871 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\গা.txt.
# Search complete! Found 1833 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ময়না.txt.
# Search complete! Found 2733 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ঠান্ডা.txt.
# Search complete! Found 10293 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ঘোর.txt.
# Search complete! Found 116476 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\পড়া.txt.
# Search complete! Found 974365 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\আগ.txt.
# Search complete! Found 11137 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\উঠা.txt.
# Search complete! Found 2802 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\চাঁদা.txt.
# Search complete! Found 149162 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ঢাকা.txt.
# Search complete! Found 0 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\উপায়.txt.
# Search complete! Found 2896 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\তুলা.txt.
# Search complete! Found 3647 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ধোঁয়া.txt.
# Search complete! Found 17217 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ঘন.txt.
# Search complete! Found 970146 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\পর.txt.
# Search complete! Found 4839 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\কপি.txt.
# Search complete! Found 23929 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\জিন.txt.
# Search complete! Found 341785 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\সার.txt.
# Search complete! Found 17503 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\পালা.txt.
# Search complete! Found 48161 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\পাড়া.txt.
# Search complete! Found 596 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ফিট.txt.
# Search complete! Found 99747 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\চাপ.txt.
# Search complete! Found 517230 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বাড়ি.txt.
# Search complete! Found 68937 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বয়স.txt.
# Search complete! Found 4648 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বাটা.txt.
# Search complete! Found 1180313 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\চা.txt.
# Search complete! Found 5184 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\পাতি.txt.
# Search complete! Found 35637 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ফেলা.txt.
# Search complete! Found 31717 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\জাল.txt.
# Search complete! Found 1427 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\পেঁচ.txt.
# Search complete! Found 14730 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\হাওয়া.txt.
# Search complete! Found 246 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\মটকা.txt.
# Search complete! Found 103687 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\জমি.txt.
# Search complete! Found 3136 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\চাবি.txt.
# Search complete! Found 217312 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\কথা.txt.
# Search complete! Found 45404 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\রূপ.txt.
# Search complete! Found 4979 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বিন্দু.txt.
# Search complete! Found 4604 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\খাতা.txt.
# Search complete! Found 65649 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\শাখা.txt.
# Search complete! Found 27185 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\দরজা.txt.
# Search complete! Found 6325 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\কান্ড.txt.
# Search complete! Found 2934 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বাকী.txt.
# Search complete! Found 608361 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\নাম.txt.
# Search complete! Found 2934 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বাকী.txt.
# Search complete! Found 435935 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ঘটনা.txt.
# Search complete! Found 1836 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\বাজে.txt.
# Search complete! Found 8849 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\দাগ.txt.
# Search complete! Found 14372 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\পাত্র.txt.
# Search complete! Found 115951 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\দ্বার.txt.
# Search complete! Found 95962 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentence_indic\ডাক.txt.

# %% [markdown]
# ****BNWaC Bengali Corpus via SketchEngine (Tokenized)****

# %%
# ---- Standard library imports: filesystem paths/listing, regex utilities, CSV (unused; left for potential extensions)
import os
import re
import csv


# Target keyword list (lemmas) to search for in the corpus
keywords = [
    'অর্থ', 'কপাল', 'রাস্তা', 'মাথা', 'বল', 'হাত', 'ফল', 'চোখ', 'কর', 'পাকা', 'বর', 'জল', 'এঁটে', 'বর্ণ', 'মধু',
    'গভীর', 'তার', 'মূল', 'মুখ', 'কাজ', 'অন্ধকার', 'ঘর', 'ছত্র', 'বক', 'জাম', 'ধরা', 'দাঁড়া', 'গোলা', 'ঝুল', 'কামাই',
    'চড়', 'সন্ধি', 'ফাঁক', 'ঝড়', 'সোজা', 'পটল', 'কাটা', 'জানালা', 'আম', 'দিক', 'কুঁজো', 'বাঁশ', 'বেলা', 'বাজি',
    'তাড়া', 'সারা', 'আগুন', 'সই', 'পথ', 'দল', 'পদ', 'কালা', 'ডিম', 'গুলি', 'বিষয়', 'বিরোধ', 'নয়', 'কান', 'দম',
    'হেলা', 'কুল', 'মাত', 'বন্ধ', 'ঝোলা', 'চড়া', 'রস', 'মাটি', 'মালা', 'ধন', 'পাল', 'কর্ণ', 'আকাশ', 'शীর্ষ',
    'চিহ্ন', 'লাঠি', 'আকা', 'পুষ্কর', 'নাক', 'টোকা', 'শিশু', 'গজ', 'লাই', 'হল', 'স্বামী', 'স্পষ্ট', 'সামান্য',
    'পিচ', 'পাহাড়', 'গা', 'ময়না', 'ঠান্ডা', 'ঘোর', 'পড়া', 'আগ', 'উঠা', 'চাঁদা', 'ঢাকা', 'উপায়', 'তুলা', 'ধোঁয়া',
    'ঘন', 'পর', 'কপি', 'জিন', 'সার', 'পালা', 'পাড়া', 'ফিট', 'চাপ', 'বাড়ি', 'বয়স', 'বাটা', 'চা', 'পাতি', 'ফেলা',
    'জাল', 'পেঁচ', 'হাওয়া', 'মটকা', 'জমি', 'চাবি','কথা','রূপ','বিন্দু','খাতা','শাখা','দরজা','কান্ড','বাকী','নাম','বাকী',
    'ঘটনা','বাজে','দাগ','পাত্র','দ্বার', 'ডাক'
]


# Comprehensive list of common Bangla inflectional suffixes and standalone vowel diacritics
# These are appended to keywords in a regex to catch inflected forms, with word-boundary enforcement.
# Full list of inflectional suffixes + single vowels
suffixes = [
    '', 'কে', 'কেই', 'কেও', 'কেওই', 'কো', 'গুলা', 'গুলা-গুলা', 'গুলাগুলি', 'গুলাগো',
    'গুলান', 'গুলানা', 'গুলানো', 'গুলার', 'গুলারই', 'গুলারও', 'গুলারাই', 'গুলারে', 'গুলারেই', 'গুলারেইও',
    'গুলারটাও', 'গুলারি', 'গুলাটারে', 'গুলাডা', 'গুলাডারে', 'গুলিকেও', 'গুলিকে', 'গুলিকো', 'গুলিতে',
    'গুলিতো', 'গুলিতেও', 'গুলিতেই', 'গুলির', 'গুলিরই', 'গুলিরও', 'গুলিরেই', 'গুলিও', 'গুলিয়েই', 'গুলিয়েও',
    'গুলো', 'গুলাই', 'গুলাইও', 'গুলোই', 'গুলো-গুলো', 'গুলোকেই', 'গুলোকেও', 'গুলোতে', 'গুলোয়', 'গুলোর',
    'গুলোরই', 'গুলোরও', 'গুলোরটাই', 'গুলোরে', 'গুলোরেই', 'গুলান', 'খানা', 'খানাকে', 'খানাতে', 'খানার', 'খানায়',
    'চ্ছে', 'ছে', 'ছেন', 'ছো', 'ছি', 'ছিস', 'ছিসি', 'ছিসেন', 'ছিল', 'ছিলা', 'ছিলাই', 'ছিলাম', 'ছিলি',
    'ছিলে', 'ছিলে না', 'ছিলেন', 'ছিলেনা', 'ছিলনা', 'ছিলো', 'জন', 'জনগো', 'জনকে', 'জনেরা', 'জনের', 'জনে',
    'তা', 'টা', 'টা-টা', 'টাগো', 'টাই', 'টাইও', 'টাইনা', 'টাইওনা', 'টার', 'টারই', 'টারও', 'টারেও',
    'টারটাও', 'টারে', 'টারেই', 'টি', 'টি-টি', 'টিই', 'টিা', 'টিাে', 'টিাও', 'টিায়', 'টিেই', 'টিতে', 'টিতেও',
    'টিতেই', 'টিকে', 'টিকেই', 'টিকেও', 'টির', 'টিরই', 'টিরও', 'টিরে', 'টিরেই', 'টিরটাই', 'টিও', 'টিওনা',
    'টিনাও', 'টিনাওনা', 'টাতো', 'টাতেও', 'টাতে', 'টাকে', 'টায়', 'তাচ্ছি', 'তাছি', 'তবে', 'ত', 'তাম',
    'তি', 'তে', 'তেও', 'তেওই', 'তেওনা', 'তেই', 'তেইও', 'তেন', 'তের', 'তেরই', 'তেরও', 'তেরাই', 'তেরা', 'তেও', 'তো', 'তো',
    'তোও', 'থেকে', 'থেকেই', 'থেকেই না', 'থেকেও', 'থেকেও না', 'দিয়ে', 'দিয়েও', 'দিয়ো', 'দিয়েও না',
    'দের', 'দেরকেই', 'দেরকে', 'দেরকেও', 'দেররাও', 'দেররেই', 'দেররে', 'দেরই', 'দেরও', 'দেরওয়', 'দেরে', 'দেরেই',
    'দেরটাই', 'দেরটাইও', 'দেরনা', 'নাই', 'নাছে', 'নাছি', 'না', 'না’', 'নেই', 'নেও', 'নেওনা', 'নাও', 'নাই', 'নেই', 'ই',
    'ইও', 'ইনা', 'ইওনা', 'ইরা', 'ইগো', 'ইনাই', 'ইতে', 'ইয়', 'ইয়েই', 'ইয়েও', 'ও', 'ওগো', 'ওরা', 'ওরাও', 'ওরাওনা', 'ওরাই',
    'ওদের', 'ওদেরকেও', 'ওদেরকে', 'ওদেররাও', 'ওদেরনা', 'ওদেরই', 'ওদেরও', 'ওদেরটাই', 'ওনি', 'ওন', 'ওনা',
    'এ', 'এতে', 'এরই', 'আমেরটাই', 'ব', 'বে', 'বেন', 'বেনা', 'বেনে', 'বিনা', 'বিনা না', 'বি', 'বো', 'বো না', 'বোনে',
    'বুলছি', 'মেয়েরা', 'পান', 'পানোর', 'পানেও', 'রা', 'রা’', 'রাই', 'রাইও', 'রাইনা', 'রাে', 'রাগো', 'রাও', 'রাওই', 'রাওনা',
    'রাটা', 'রেই', 'রেইও', 'র', 'রের', 'রেরই', 'রেরও', 'রেরে', 'রও', 'লাম', 'লামও', 'লামেই', 'লামনা', 'লি', 'লে', 'লেন', 'লো',
    'তাম', 'তেন', 'হয়', 'হয়েই', 'হয়না', 'সহ', 'সহেই', 'সহেই না', 'সহেও', 'সহেও না', 'য়', 'য়াটা', 'য়ে', 'য়েই', 'য়েই না',
    'য়েইও', 'য়ো', 'য়ো না', 'য়েও', 'য়েও না', 'য়েটা', 'য়াছে', 'য়াছি', 'য়াছিল', 'য়াছিলাম', 'য়াছেন', 'য়াছিলে', 'য়াছিলেন'
] + ['া', 'ি', 'ু', 'ে', 'ো', 'ৈ', 'ৌ']  # Vowel endings (no derivation)


# Function: find_sentences_with_word
# Purpose : For a given keyword (lemma), search all .txt files in a directory and collect sentences containing 
# the lemma or lemma+suffix (from the list). Builds a regex that matches lemma + any suffix from `suffixes`, then enforces a
# word boundary by requiring a trailing whitespace, punctuation, or string end. Uses a negative lookbehind for 
# ASCII word chars to avoid partial matches there. Results are written to <lemma>.txt in the output directory.
# Inputs  :
#   input_directory (str): Path to folder with input .txt files (one sentence per line).
#   lemma_word      (str): The base keyword/lemma to search for.
#   output_directory(str): Path to folder where matched sentences file will be saved.
# Outputs :
#   None (side effects): Writes a text file with one matched sentence per line
#   Prints a completion summary with match count.
def find_sentences_with_word(input_directory, lemma_word, output_directory):
    # Prebuild a suffix alternation pattern, sorted by length (longest first) to ensure greedy matching
    # Make regex pattern for lemma + suffixes, must be followed by boundary (not a Bengali char)
    suffix_regex = '|'.join(sorted([re.escape(s) for s in suffixes if s], key=len, reverse=True))
    # Compose the final pattern:
    #   - capture lemma + one of the suffixes
    #   - enforce ending at boundary: whitespace, Bangla danda/ punctuation, bracket/quote, or string end
    # Force match to end at space, punctuation, or string end
    # Note: [\s।,;:.?!\]\["'\)\(]|$ will match boundary after lemma+suffix
    pattern = re.compile(
        rf'(?<!\w)({re.escape(lemma_word)}({suffix_regex}))(?:[\s।,;:.?!\]\["\'\)\(]|$)'
    )

    # Accumulate matched sentences
    matches = []
    # Iterate all files in the input directory
    for file_name in os.listdir(input_directory):
        # Process only .txt files
        if file_name.endswith('.txt'):
            # Full path to the file
            file_path = os.path.join(input_directory, file_name)
            # Open the file in UTF-8 and scan line by line
            with open(file_path, 'r', encoding='utf-8') as infile:
                for line in infile:
                    # Strip whitespace/newlines
                    line = line.strip()
                    # If the compiled pattern matches anywhere in the line, keep it
                    if pattern.search(line):
                        matches.append([line])

    # Build output filename for this lemma and write one sentence per line
    # Write to txt
    output_file = os.path.join(output_directory, f"{lemma_word}.txt")
    with open(output_file, 'w', encoding='utf-8') as outfile:
        for row in matches:
            outfile.write(row[0] + '\n')

    # Print completion summary with count and destination path
    print(f"Search complete! Found {len(matches)} matching sentences saved to {output_file}.")


# ---- Input/Output directories for the corpus and where to save per-keyword matches
input_directory = r"C:\Users\Student\Documents\Bangla\Sketch engine"
output_directory = r"C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine"

# ---- Run the search for every keyword in the list, producing one output file per lemma
for lemma_word in keywords:
    find_sentences_with_word(input_directory, lemma_word, output_directory)
# Out:
# Search complete! Found 2062 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\অর্থ.txt.
# Search complete! Found 1596 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\কপাল.txt.
# Search complete! Found 11415 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\রাস্তা.txt.
# Search complete! Found 7492 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\মাথা.txt.
# Search complete! Found 116495 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\বল.txt.
# Search complete! Found 27488 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\হাত.txt.
# Search complete! Found 22118 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ফল.txt.
# Search complete! Found 13715 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\চোখ.txt.
# Search complete! Found 459865 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\কর.txt.
# Search complete! Found 698 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\পাকা.txt.
# Search complete! Found 7545 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\বর.txt.
# Search complete! Found 7006 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\জল.txt.
# Search complete! Found 32 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\এঁটে.txt.
# Search complete! Found 2915 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\বর্ণ.txt.
# Search complete! Found 5435 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\মধু.txt.
# Search complete! Found 1276 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\গভীর.txt.
# Search complete! Found 56651 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\তার.txt.
# Search complete! Found 3981 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\মূল.txt.
# Search complete! Found 21587 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\মুখ.txt.
# Search complete! Found 12654 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\কাজ.txt.
# Search complete! Found 5254 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\অন্ধকার.txt.
# Search complete! Found 17481 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ঘর.txt.
# Search complete! Found 30 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ছত্র.txt.
# Search complete! Found 6440 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\বক.txt.
# Search complete! Found 2335 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\জাম.txt.
# Search complete! Found 4024 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ধরা.txt.
# Search complete! Found 2967 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\দাঁড়া.txt.
# Search complete! Found 304 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\গোলা.txt.
# Search complete! Found 2322 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ঝুল.txt.
# Search complete! Found 8 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\কামাই.txt.
# Search complete! Found 3576 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\চড়.txt.
# Search complete! Found 891 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\সন্ধি.txt.
# Search complete! Found 10318 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ফাঁক.txt.
# Search complete! Found 2614 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ঝড়.txt.
# Search complete! Found 6 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\সোজা.txt.
# Search complete! Found 26 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\পটল.txt.
# Search complete! Found 8319 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\কাটা.txt.
# Search complete! Found 5959 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\জানালা.txt.
# Search complete! Found 87919 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\আম.txt.
# Search complete! Found 42105 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\দিক.txt.
# Search complete! Found 15 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\কুঁজো.txt.
# Search complete! Found 1251 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\বাঁশ.txt.
# Search complete! Found 1477 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\বেলা.txt.
# Search complete! Found 567 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\বাজি.txt.
# Search complete! Found 230 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\তাড়া.txt.
# Search complete! Found 715 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\সারা.txt.
# Search complete! Found 3414 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\আগুন.txt.
# Search complete! Found 434 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\সই.txt.
# Search complete! Found 16110 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\পথ.txt.
# Search complete! Found 9234 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\দল.txt.
# Search complete! Found 10455 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\পদ.txt.
# Search complete! Found 7426 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\কালা.txt.
# Search complete! Found 1039 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ডিম.txt.
# Search complete! Found 6645 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\গুলি.txt.
# Search complete! Found 0 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\বিষয়.txt.
# Search complete! Found 1073 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\বিরোধ.txt.
# Search complete! Found 0 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\নয়.txt.
# Search complete! Found 12530 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\কান.txt.
# Search complete! Found 2018 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\দম.txt.
# Search complete! Found 68 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\হেলা.txt.
# Search complete! Found 3845 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\কুল.txt.
# Search complete! Found 3686 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\মাত.txt.
# Search complete! Found 5832 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\বন্ধ.txt.
# Search complete! Found 372 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ঝোলা.txt.
# Search complete! Found 0 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\চড়া.txt.
# Search complete! Found 2876 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\রস.txt.
# Search complete! Found 14951 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\মাটি.txt.
# Search complete! Found 602 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\মালা.txt.
# Search complete! Found 3701 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ধন.txt.
# Search complete! Found 9266 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\পাল.txt.
# Search complete! Found 298 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\কর্ণ.txt.
# Search complete! Found 7203 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\আকাশ.txt.
# Search complete! Found 3424 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\শীর্ষ.txt.
# Search complete! Found 1110 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\চিহ্ন.txt.
# Search complete! Found 2590 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\লাঠি.txt.
# Search complete! Found 2733 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\আকা.txt.
# Search complete! Found 1 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\পুষ্কর.txt.
# Search complete! Found 12077 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\নাক.txt.
# Search complete! Found 108 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\টোকা.txt.
# Search complete! Found 13981 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\শিশু.txt.
# Search complete! Found 4599 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\গজ.txt.
# Search complete! Found 432 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\লাই.txt.
# Search complete! Found 61988 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\হল.txt.
# Search complete! Found 6460 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\স্বামী.txt.
# Search complete! Found 116 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\স্পষ্ট.txt.
# Search complete! Found 95 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\সামান্য.txt.
# Search complete! Found 205 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\পিচ.txt.
# Search complete! Found 5172 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\পাহাড়.txt.
# Search complete! Found 21957 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\গা.txt.
# Search complete! Found 155 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ময়না.txt.
# Search complete! Found 177 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ঠান্ডা.txt.
# Search complete! Found 1559 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ঘোর.txt.
# Search complete! Found 5318 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\পড়া.txt.
# Search complete! Found 28582 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\আগ.txt.
# Search complete! Found 6358 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\উঠা.txt.
# Search complete! Found 1521 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\চাঁদা.txt.
# Search complete! Found 7062 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ঢাকা.txt.
# Search complete! Found 0 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\উপায়.txt.
# Search complete! Found 2966 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\তুলা.txt.
# Search complete! Found 364 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ধোঁয়া.txt.
# Search complete! Found 703 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ঘন.txt.
# Search complete! Found 32856 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\পর.txt.
# Search complete! Found 1203 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\কপি.txt.
# Search complete! Found 1705 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\জিন.txt.
# Search complete! Found 23820 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\সার.txt.
# Search complete! Found 4783 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\পালা.txt.
# Search complete! Found 2456 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\পাড়া.txt.
# Search complete! Found 138 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ফিট.txt.
# Search complete! Found 6311 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\চাপ.txt.
# Search complete! Found 18798 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\বাড়ি.txt.
# Search complete! Found 1980 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\বয়স.txt.
# Search complete! Found 2626 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\বাটা.txt.
# Search complete! Found 46513 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\চা.txt.
# Search complete! Found 264 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\পাতি.txt.
# Search complete! Found 5820 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\ফেলা.txt.
# Search complete! Found 5061 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\জাল.txt.
# Search complete! Found 153 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\পেঁচ.txt.
# Search complete! Found 1123 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\হাওয়া.txt.
# Search complete! Found 8 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\মটকা.txt.
# Search complete! Found 12373 matching sentences saved to C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine\জমি.txt.

# %% [markdown]
# **Bangla Multi-Corpus Sentence Merger & Shuffler**
#
# This script consolidates per-lemma sentence lists from multiple corpora. For every lemma (one lemma per .txt filename), it:
#
#  1) Discovers all lemmas present across the given source folders.
#  2) Loads every available file for that lemma, strips blank lines, and concatenates all sentences.
#  3) Shuffles the merged sentences to reduce corpus-order bias.
#  4) Writes a single combined file per lemma to a target folder, reporting how many sentences were saved.

# %%
import os                                                     # Filesystem utilities: paths, directory ops
import glob                                                   # Pattern-based file discovery (e.g., *.txt)
import random                                                 # Random shuffling to reduce corpus-order bias

# Folders containing your txt files for each corpus
folders = [                                                   # List of source directories to merge from
    r'C:\Users\Student\Documents\Bangla\extracted_sentences_indic',            # Corpus 1
    r'C:\Users\Student\Documents\Bangla\extracted_sentences_prothom_alo',      # Corpus 2
    r'C:\Users\Student\Documents\Bangla\extracted_sentences_sketch_engine',    # Corpus 3
]
output_folder = r'C:\Users\Student\Documents\Bangla\final_dataset'             # Destination directory for merged files
os.makedirs(output_folder, exist_ok=True)                      # Create destination if missing (no error if exists)

# Get all unique word filenames from all corpora
all_files = []                                                 # Accumulator for all discovered .txt paths
for folder in folders:                                         # Iterate each source directory
    all_files.extend(glob.glob(os.path.join(folder, '*.txt'))) # Append all .txt files from this folder
words = set(os.path.splitext(os.path.basename(f))[0] for f in all_files)  # Unique lemma names (filename without extension)

for word in words:                                             # Process each lemma independently
    sentences = []                                             # Collector for sentences across all corpora for this lemma
    for folder in folders:                                     # Check each source folder for this lemma’s file
        file_path = os.path.join(folder, word + '.txt')        # Expected path for the lemma file in this folder
        if os.path.isfile(file_path):                          # Only proceed if the file exists here
            with open(file_path, 'r', encoding='utf-8') as f:  # Open lemma file (UTF-8)
                lines = [line.strip() for line in f if line.strip()]  # Read non-empty lines, strip whitespace
                sentences.extend(lines)                        # Add sentences from this corpus to the pool
    # Shuffle to remove bias from corpus order
    random.shuffle(sentences)                                  # Randomize order to mitigate source ordering effects
    # Save the combined file
    output_path = os.path.join(output_folder, word + '.txt')   # Path for the merged output file for this lemma
    with open(output_path, 'w', encoding='utf-8') as out:      # Create/overwrite the merged file
        for line in sentences:                                 # Write each sentence on its own line
            out.write(line + '\n')                             # Persist sentence with newline
    print(f"{word}: {len(sentences)} sentences combined and saved.")  # Progress report per lemma

print("All datasets combined and shuffled.")                   # Final completion message
# Out:
# তার: 1962429 sentences combined and saved.
# পাল: 96179 sentences combined and saved.
# বন্ধ: 240872 sentences combined and saved.
# খাতা: 10507 sentences combined and saved.
# চা: 1764345 sentences combined and saved.
# পেঁচ: 1803 sentences combined and saved.
# বাটা: 8736 sentences combined and saved.
# কান্ড: 6647 sentences combined and saved.
# উঠা: 18063 sentences combined and saved.
# চড়: 75160 sentences combined and saved.
# চিহ্ন: 6121 sentences combined and saved.
# পাতি: 7550 sentences combined and saved.
# রাস্তা: 170689 sentences combined and saved.
# পাহাড়: 61591 sentences combined and saved.
# ঢাকা: 334607 sentences combined and saved.
# পুষ্কর: 110 sentences combined and saved.
# রস: 86418 sentences combined and saved.
# গুলি: 172409 sentences combined and saved.
# বাজে: 2975 sentences combined and saved.
# নাক: 359389 sentences combined and saved.
# ধন: 148487 sentences combined and saved.
# বাজি: 29126 sentences combined and saved.
# জল: 102350 sentences combined and saved.
# এঁটে: 1916 sentences combined and saved.
# হল: 2150580 sentences combined and saved.
# চাঁদা: 6088 sentences combined and saved.
# কুল: 167430 sentences combined and saved.
# জমি: 175428 sentences combined and saved.
# পালা: 28362 sentences combined and saved.
# ডিম: 7455 sentences combined and saved.
# ধরা: 71923 sentences combined and saved.
# গোলা: 13669 sentences combined and saved.
# অন্ধকার: 38101 sentences combined and saved.
# কপি: 7834 sentences combined and saved.
# শীর্ষ: 51534 sentences combined and saved.
# ঝুল: 35637 sentences combined and saved.
# চোখ: 205084 sentences combined and saved.
# সামান্য: 4958 sentences combined and saved.
# শাখা: 110812 sentences combined and saved.
# উপায়: 7108 sentences combined and saved.
# কাটা: 123387 sentences combined and saved.
# বয়স: 73794 sentences combined and saved.
# বর: 388289 sentences combined and saved.
# চাপ: 138990 sentences combined and saved.
# সার: 510406 sentences combined and saved.
# ঘটনা: 749078 sentences combined and saved.
# সোজা: 206 sentences combined and saved.
# বাঁশ: 14934 sentences combined and saved.
# আকা: 68231 sentences combined and saved.
# জাম: 55267 sentences combined and saved.
# শিশু: 402231 sentences combined and saved.
# ঠান্ডা: 4907 sentences combined and saved.
# দাগ: 12063 sentences combined and saved.
# কামাই: 201 sentences combined and saved.
# বাড়ি: 570032 sentences combined and saved.
# বেলা: 32021 sentences combined and saved.
# মাটি: 193215 sentences combined and saved.
# বক: 270875 sentences combined and saved.
# পদ: 278748 sentences combined and saved.
# আগ: 1408260 sentences combined and saved.
# চাবি: 4163 sentences combined and saved.
# কর্ণ: 2117 sentences combined and saved.
# তাড়া: 5638 sentences combined and saved.
# দল: 524261 sentences combined and saved.
# ফল: 656766 sentences combined and saved.
# পটল: 552 sentences combined and saved.
# জিন: 35339 sentences combined and saved.
# মাত: 139920 sentences combined and saved.
# সারা: 18352 sentences combined and saved.
# লাঠি: 9880 sentences combined and saved.
# পথ: 342620 sentences combined and saved.
# বিন্দু: 6887 sentences combined and saved.
# মূল: 151495 sentences combined and saved.
# জাল: 48038 sentences combined and saved.
# সন্ধি: 4904 sentences combined and saved.
# দিক: 1413576 sentences combined and saved.
# ধোঁয়া: 4142 sentences combined and saved.
# রূপ: 54395 sentences combined and saved.
# পড়া: 130329 sentences combined and saved.
# কর: 18619820 sentences combined and saved.
# ফিট: 871 sentences combined and saved.
# মটকা: 312 sentences combined and saved.
# ঘোর: 13930 sentences combined and saved.
# পাকা: 4983 sentences combined and saved.
# অর্থ: 47965 sentences combined and saved.
# কালা: 21812 sentences combined and saved.
# পর: 1386528 sentences combined and saved.
# পাড়া: 54609 sentences combined and saved.
# পাত্র: 19536 sentences combined and saved.
# হাওয়া: 16318 sentences combined and saved.
# নাম: 820365 sentences combined and saved.
# সই: 12475 sentences combined and saved.
# ঘর: 323199 sentences combined and saved.
# আকাশ: 58991 sentences combined and saved.
# ঝোলা: 1822 sentences combined and saved.
# আগুন: 46888 sentences combined and saved.
# ঘন: 26663 sentences combined and saved.
# চড়া: 4083 sentences combined and saved.
# কপাল: 31416 sentences combined and saved.
# ঝড়: 29530 sentences combined and saved.
# ফাঁক: 102906 sentences combined and saved.
# কথা: 315295 sentences combined and saved.
# জানালা: 25216 sentences combined and saved.
# মাথা: 127501 sentences combined and saved.
# দম: 46309 sentences combined and saved.
# গা: 657264 sentences combined and saved.
# ময়না: 2041 sentences combined and saved.
# মালা: 26251 sentences combined and saved.
# তুলা: 7042 sentences combined and saved.
# স্বামী: 117408 sentences combined and saved.
# বিষয়: 374044 sentences combined and saved.
# মধু: 31883 sentences combined and saved.
# নয়: 60342 sentences combined and saved.
# কুঁজো: 249 sentences combined and saved.
# লাই: 20456 sentences combined and saved.
# ফেলা: 57843 sentences combined and saved.
# দ্বার: 137254 sentences combined and saved.
# পিচ: 7562 sentences combined and saved.
# বর্ণ: 91781 sentences combined and saved.
# দরজা: 38321 sentences combined and saved.
# আম: 3510735 sentences combined and saved.
# স্পষ্ট: 5658 sentences combined and saved.
# গভীর: 24516 sentences combined and saved.
# গজ: 42793 sentences combined and saved.
# হাত: 732196 sentences combined and saved.
# দাঁড়া: 85328 sentences combined and saved.
# বিরোধ: 7995 sentences combined and saved.
# টোকা: 1980 sentences combined and saved.
# হেলা: 1864 sentences combined and saved.
# কান: 287289 sentences combined and saved.
# বল: 5099765 sentences combined and saved.
# কাজ: 502343 sentences combined and saved.
# মুখ: 537290 sentences combined and saved.
# ছত্র: 1025 sentences combined and saved.
# বাকী: 3358 sentences combined and saved.
# All datasets combined and shuffled.
